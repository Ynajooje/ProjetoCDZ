# %% [markdown]
# <a href="https://colab.research.google.com/github/Ynajooje/ProjetoCDZ/blob/main/cursoAlura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape [0], df.shape [1]
print ("linhas:", linhas)
print ("colunas:", colunas)
# Out:
# linhas: 133349
# colunas: 11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
# Create a dictionary with the current column names and their Portuguese translations
new_column_names = {
    'work_year': 'ano',
    'experience_level': 'nivel_experiencia',
    'employment_type': 'tipo_emprego',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'salario_em_usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'localizacao_empresa',
    'company_size': 'porte_empresa'
}

# Rename the columns using the dictionary
df.rename(columns=new_column_names, inplace=True)

# Display the updated column names to confirm the changes
display(df.columns)
# Out:
# Index(['ano', 'nivel_experiencia', 'tipo_emprego', 'cargo', 'salario', 'moeda',
#        'salario_em_usd', 'residencia', 'remoto', 'localizacao_empresa',
#        'porte_empresa'],
#       dtype='object')

# %%
df["nivel_experiencia"].value_counts()
# Out:
# nivel_experiencia
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df["tipo_emprego"].value_counts()
# Out:
# tipo_emprego
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df["remoto"].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
# Create a dictionary to map the English experience levels to Portuguese
experience_level_map = {
    'SE': 'Senior',
    'MI': 'Pleno',
    'EN': 'Júnior',
    'EX': 'Executivo'
}

# Apply the mapping to the 'nivel_experiencia' column
df['nivel_experiencia'] = df['nivel_experiencia'].replace(experience_level_map)

# Display the updated value counts to confirm the changes
display(df['nivel_experiencia'].value_counts())
# Out:
# nivel_experiencia
# Senior       77241
# Pleno        40465
# Júnior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
# Create a dictionary to map the English employment types to Portuguese
employment_type_map = {
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Tempo Parcial',
    'FL': 'Freelancer'
}

# Apply the mapping to the 'tipo_emprego' column using replace
df['tipo_emprego'] = df['tipo_emprego'].replace(employment_type_map)

# Display the updated value counts to confirm the changes
display(df['tipo_emprego'].value_counts())
# Out:
# tipo_emprego
# Tempo Integral    132563
# Contrato             394
# Tempo Parcial        376
# Freelancer            16
# Name: count, dtype: int64

# %%
# Create a dictionary to map the remote ratio to Portuguese terms
remote_map = {
    0: 'Presencial',
    50: 'Híbrido',
    100: 'Remoto'
}

# Apply the mapping to the 'remoto' column using replace
df['remoto'] = df['remoto'].replace(remote_map)

# Display the updated value counts to confirm the changes
display(df['remoto'].value_counts())
# Out:
# remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano nivel_experiencia    tipo_emprego               cargo  salario  \
# 0  2025.0            Senior  Tempo Integral  Solutions Engineer   214000
# 1  2025.0            Senior  Tempo Integral  Solutions Engineer   136000
# 2  2025.0             Pleno  Tempo Integral       Data Engineer   158800
# 3  2025.0             Pleno  Tempo Integral       Data Engineer   139200
# 4  2025.0            Júnior  Tempo Integral       Data Engineer    90000
#
#   moeda  salario_em_usd residencia      remoto localizacao_empresa  \
# 0   USD          214000         US      Remoto                  US
# 1   USD          136000         US      Remoto                  US
# 2   USD          158800         AU  Presencial                  AU
# 3   USD          139200         AU  Presencial                  AU
# 4   USD           90000         US  Presencial                  US
#
#   porte_empresa
# 0             M
# 1             M
# 2             M
# 3             M
# 4             M

# %%
df.describe (include="object")
# Out:
#        nivel_experiencia    tipo_emprego           cargo   moeda residencia  \
# count             133349          133349          133349  133349     133349
# unique                 4               4             390      26        102
# top               Senior  Tempo Integral  Data Scientist     USD         US
# freq               77241          132563           17314  126140     119579
#
#             remoto localizacao_empresa porte_empresa
# count       133349              133349        133349
# unique           3                  95             3
# top     Presencial                  US             M
# freq        105312              119641        129561

# %%
df.head()
# Out:
#       ano nivel_experiencia    tipo_emprego               cargo  salario  \
# 0  2025.0            Senior  Tempo Integral  Solutions Engineer   214000
# 1  2025.0            Senior  Tempo Integral  Solutions Engineer   136000
# 2  2025.0             Pleno  Tempo Integral       Data Engineer   158800
# 3  2025.0             Pleno  Tempo Integral       Data Engineer   139200
# 4  2025.0            Júnior  Tempo Integral       Data Engineer    90000
#
#   moeda  salario_em_usd residencia      remoto localizacao_empresa  \
# 0   USD          214000         US      Remoto                  US
# 1   USD          136000         US      Remoto                  US
# 2   USD          158800         AU  Presencial                  AU
# 3   USD          139200         AU  Presencial                  AU
# 4   USD           90000         US  Presencial                  US
#
#   porte_empresa
# 0             M
# 1             M
# 2             M
# 3             M
# 4             M

# %%
df.isnull().sum()
# Out:
# ano                    10
# nivel_experiencia       0
# tipo_emprego            0
# cargo                   0
# salario                 0
# moeda                   0
# salario_em_usd          0
# residencia              0
# remoto                  0
# localizacao_empresa     0
# porte_empresa           0
# dtype: int64

# %%
df['ano'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano nivel_experiencia    tipo_emprego                      cargo  \
# 5588    NaN            Senior  Tempo Integral            Product Manager
# 59692   NaN             Pleno  Tempo Integral                   Engineer
# 59710   NaN            Júnior  Tempo Integral             Data Scientist
# 59759   NaN            Senior  Tempo Integral          Software Engineer
# 59789   NaN            Senior  Tempo Integral                   Engineer
# 131000  NaN            Senior  Tempo Integral  Machine Learning Engineer
# 131006  NaN            Senior  Tempo Integral     Data Analytics Manager
# 133054  NaN            Júnior  Tempo Integral             Data Scientist
# 133281  NaN             Pleno  Tempo Integral  Machine Learning Engineer
# 133317  NaN             Pleno  Tempo Integral             Data Scientist
#
#         salario moeda  salario_em_usd residencia      remoto  \
# 5588     184500   USD          184500         US  Presencial
# ...

# %%
import numpy as np

# %%
#Criação de um dataframe teste para teste
df_salarios=pd.DataFrame({
    'nome': ["Ana Julia", "João", "Ana Cristina", "Julio", 'Klara'],
    'salario': [4000, np.nan, 3000, np.nan, 1000000]

    })
# Calcula a média salarial e substitui os nulos pela média e arredonda os valores
df_salarios['salario_media'] = df_salarios ['salario'].fillna(df_salarios['salario'].mean().round(2))
# Calcula a mediana e substitui os nulos pela mediana
df_salarios['salario_mediana'] = df_salarios ['salario'].fillna(df_salarios['salario'].median())
df_salarios
# Out:
#            nome    salario  salario_media  salario_mediana
# 0     Ana Julia     4000.0        4000.00           4000.0
# 1          João        NaN      335666.67           4000.0
# 2  Ana Cristina     3000.0        3000.00           3000.0
# 3         Julio        NaN      335666.67           4000.0
# 4         Klara  1000000.0     1000000.00        1000000.0

# %%
df_temperaturas= pd.DataFrame ({
   'dia': ["Segunda", "Terça", "Quarta", "Quinta", 'Sexta'],
    'Temperatura': [30, np.nan, np.nan, 28, 27]
})

df_temperaturas ["preenchido_ffill"] = df_temperaturas ["Temperatura"].ffill()
df_temperaturas
# Out:
#        dia  Temperatura  preenchido_ffill
# 0  Segunda         30.0              30.0
# 1    Terça          NaN              30.0
# 2   Quarta          NaN              30.0
# 3   Quinta         28.0              28.0
# 4    Sexta         27.0              27.0

# %%
df_temperaturas= pd.DataFrame ({
   'dia': ["Segunda", "Terça", "Quarta", "Quinta", 'Sexta'],
    'Temperatura': [30, np.nan, np.nan, 28, 27]
})

df_temperaturas ["preenchido_bffill"] = df_temperaturas ["Temperatura"].bfill()
df_temperaturas
# Out:
#        dia  Temperatura  preenchido_bffill
# 0  Segunda         30.0               30.0
# 1    Terça          NaN               28.0
# 2   Quarta          NaN               28.0
# 3   Quinta         28.0               28.0
# 4    Sexta         27.0               27.0

# %%
df_cidades = pd.DataFrame({
    'nome': ["Ana Julia", "João", "Ana Cristina", "Julio", 'Klara'],
    'Cidade': ["São Paulo", np.nan, "Distrito federal", np.nan, "Belém" ]
})

df_cidades['cidade_preenchida'] = df_cidades["Cidade"].fillna("nao informado") # Corrigido a sintaxe para criar a nova coluna
display(df_cidades) # Adicionado display para mostrar o resultado
# Out:
#            nome            Cidade cidade_preenchida
# 0     Ana Julia         São Paulo         São Paulo
# 1          João               NaN     nao informado
# 2  Ana Cristina  Distrito federal  Distrito federal
# 3         Julio               NaN     nao informado
# 4         Klara             Belém             Belém

# %%
df_limpo = df.dropna()
df_limpo.isnull().sum()
# Out:
# ano                    0
# nivel_experiencia      0
# tipo_emprego           0
# cargo                  0
# salario                0
# moeda                  0
# salario_em_usd         0
# residencia             0
# remoto                 0
# localizacao_empresa    0
# porte_empresa          0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano nivel_experiencia    tipo_emprego               cargo  salario  \
# 0  2025.0            Senior  Tempo Integral  Solutions Engineer   214000
# 1  2025.0            Senior  Tempo Integral  Solutions Engineer   136000
# 2  2025.0             Pleno  Tempo Integral       Data Engineer   158800
# 3  2025.0             Pleno  Tempo Integral       Data Engineer   139200
# 4  2025.0            Júnior  Tempo Integral       Data Engineer    90000
#
#   moeda  salario_em_usd residencia      remoto localizacao_empresa  \
# 0   USD          214000         US      Remoto                  US
# 1   USD          136000         US      Remoto                  US
# 2   USD          158800         AU  Presencial                  AU
# 3   USD          139200         AU  Presencial                  AU
# 4   USD           90000         US  Presencial                  US
#
#   porte_empresa
# 0             M
# 1             M
# 2             M
# 3             M
# 4             M

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ano                  133339 non-null  float64
#  1   nivel_experiencia    133339 non-null  object
#  2   tipo_emprego         133339 non-null  object
#  3   cargo                133339 non-null  object
#  4   salario              133339 non-null  int64
#  5   moeda                133339 non-null  object
#  6   salario_em_usd       133339 non-null  int64
#  7   residencia           133339 non-null  object
#  8   remoto               133339 non-null  object
#  9   localizacao_empresa  133339 non-null  object
#  10  porte_empresa        133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %%
df_limpo = df_limpo.assign(ano= df_limpo ['ano'].astype('int64'))

# %%
df_limpo.head()
# Out:
#     ano nivel_experiencia    tipo_emprego               cargo  salario moeda  \
# 0  2025            Senior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025            Senior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025             Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025             Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025            Júnior  Tempo Integral       Data Engineer    90000   USD
#
#    salario_em_usd residencia      remoto localizacao_empresa porte_empresa
# 0          214000         US      Remoto                  US             M
# 1          136000         US      Remoto                  US             M
# 2          158800         AU  Presencial                  AU             M
# 3          139200         AU  Presencial                  AU             M
# 4           90000         US  Presencial                  US             M

# %%
df_limpo['nivel_experiencia'].value_counts().plot(kind='bar', title= "Distribuição de níveis de experiência")
# Out:
# <Axes: title={'center': 'Distribuição de níveis de experiência'}, xlabel='nivel_experiencia'>

# %%
import seaborn as sns

# %%
sns.barplot (data= df_limpo, x= 'nivel_experiencia', y= 'salario_em_usd')
# Out:
# <Axes: xlabel='nivel_experiencia', ylabel='salario_em_usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure (figsize=(8,5))
sns.barplot (data= df_limpo, x= 'nivel_experiencia', y= 'salario_em_usd')
plt.title ('Distribuição de salários por nível de experiência')
plt.xlabel ('Nível de experiência')
plt.ylabel ('Salário médio anual (USD)')
plt.show()

# %%
df_limpo.groupby('nivel_experiencia')['salario_em_usd'].mean().sort_values (ascending=False)
# Out:
# nivel_experiencia
# Executivo    202027.667813
# Senior       172850.838301
# Pleno        143044.845979
# Júnior        99034.963267
# Name: salario_em_usd, dtype: float64

# %%
ordem= df_limpo.groupby('nivel_experiencia')['salario_em_usd'].mean().sort_values (ascending=True).index
ordem
# Out:
# Index(['Júnior', 'Pleno', 'Senior', 'Executivo'], dtype='object', name='nivel_experiencia')

# %%
plt.figure (figsize=(8,5))
sns.barplot (data= df_limpo, x= 'nivel_experiencia', y= 'salario_em_usd', order=ordem)
plt.title ('Distribuição de salários por nível de experiência')
plt.xlabel ('Nível de experiência')
plt.ylabel ('Salário médio anual (USD)')
plt.show()

# %%
plt.figure (figsize=(10,5))
sns.histplot (df_limpo ['salario_em_usd'], bins = 50, kde=True)
plt.title ('Distribuição de salários anuais')
plt.xlabel ('Salário anual (USD)')
plt.ylabel ('Frequência')
plt.show()

# %%
plt.figure (figsize=(8,5))
sns.boxplot (x=df_limpo['salario_em_usd'])
plt.title ('Boxplot salario')
plt.xlabel ('Salario em USD')
plt.show()

# %%
ordem_senioridade= ['Júnior', 'Pleno', 'Senior', 'Executivo']
plt.figure (figsize=(8,5))
sns.boxplot (x='nivel_experiencia', y='salario_em_usd', data= df_limpo, order= ordem_senioridade)
plt.title ('Boxplot distribuição salarial por nível de experiência')
plt.xlabel ('Nível de experiência')
plt.ylabel ('Salario em USD')
plt.show()

# %%
ordem_senioridade= ['Júnior', 'Pleno', 'Senior', 'Executivo']
plt.figure (figsize=(8,5))
sns.boxplot (x='nivel_experiencia', y='salario_em_usd', data= df_limpo, order= ordem_senioridade, palette='Set2', hue= 'nivel_experiencia')
plt.title ('Boxplot distribuição salarial por nível de experiência')
plt.xlabel ('Nível de experiência')
plt.ylabel ('Salario em USD')
plt.show()

# %%
import plotly.express as px

# %%
df_salario_por_senioridade = df_limpo.groupby('nivel_experiencia')['salario_em_usd'].mean().reset_index()

fig = px.bar(df_salario_por_senioridade,
             x='nivel_experiencia',
             y='salario_em_usd',
             title='Média salarial por nível de experiência',
             labels={'nivel_experiencia': 'Nível de Experiência', 'salario_em_usd': 'Média Salarial (USD)'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['Tipo_trabalho', 'quantidade']
fig = px.pie(remoto_contagem,
             names='Tipo_trabalho',
             values= 'quantidade',
             title='Distribuição de trabalho remoto')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['Tipo_trabalho', 'quantidade']
fig = px.pie(remoto_contagem,
             names='Tipo_trabalho',
             values= 'quantidade',
             title='Distribuição de trabalho remoto',
            hole= 0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['Tipo_trabalho', 'quantidade']
fig = px.pie(remoto_contagem,
             names='Tipo_trabalho',
             values= 'quantidade',
             title='Distribuição de trabalho remoto',
            hole= 0.5)
fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
